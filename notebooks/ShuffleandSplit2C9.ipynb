# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load dataframe and count number of cases positive and negative cases

# %%
isozyme2c9 = pd.read_csv('data/2c9.csv')

# %%
# Renaming the Activity Score column to conform to Python syntax
isozyme2c9.rename(columns={'p450-cyp2c9-ActivityScore': 'ActivityScore'}, inplace=True)

# %%
# Number of substances with an activity scores greater than or equal to 40
n_pos = (isozyme2c9.ActivityScore >= 40).sum()
n_pos
# Out:
# 4121

# %%
# Number of substances with an activity score below 40
n_neg = (isozyme2c9.ActivityScore < 40).sum()
n_neg
# Out:
# 13022

# %% [markdown]
# ##Downsampling the negative cases
#     This section of code shuffles the order of substances with an Activity Score below 40 (negatives). Then counts the number of substances with an Activity Score 40 or above (positives) and uses that number as a cutoff value on the list of negatives. When complete, there are an equal number of positives and negatives.
#     The seed value is set for the randomizer to ensure reproducibility. Different seeds will result in different negatives being included in the analysis set. All of the positives are always included in the resulting dataset.

# %%
# method adapted from DataRobot post about scikit-learn classification

# Downsample negative cases -- there are many more negatives than positives

indices = np.where(isozyme2c9.ActivityScore < 40)[0]
rng = np.random.RandomState(50)  # sets seed for random number generator
rng.shuffle(indices)             # different seed numbers result in different shuffle
n_pos = (isozyme2c9.ActivityScore >= 40).sum()
balanced = isozyme2c9.drop(isozyme2c9.index[indices[n_pos:]])

balanced.head(10)
# Out:
#        SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 0   842238             20  51.111824      1       0      6       1       46
# 2   842319             87  52.328274      4       0      6       0       42
# 3   842408             20  42.691135      4       0     11       0       31
# 4   842584             40  36.787930      3       0     17       0       28
# 5   842618             88  70.986168      5       0     17       2       64
# 6   842697             42  47.032688      6       0     17       0       40
# 8   842891              0  81.870926      6       0     11       2       75
# 9   842953             42  62.660240      3       0     12       1       52
# 12  843170             40  56.986618      4       0      6       0       52
# 18  843526             42  45.001102      3       0     11       0       36
#
#     a_don  a_heavy   ...     vsa_acid  vsa_base    vsa_don    vsa_hyd  \
# 0       1       21   ...            0         0   5.682576  286.85770
# 2       0       24   ...            0         0   0.000000  241.82869
# 3       0       22   ...            0         0   0.000000  191.26006
# 4       2       18   ...            0         0   0.000000  180.79523
# 5       0       31   ...            0         0   0.000000  380.40643
# 6       1       24   ...            0         0   5.682576  224.58302
# 8       1       36   ...            0         0   5.682576  385.93207
# 9       1       29   ...            0         0   0.000000  340.08496
# 12      1       26   ...            0         0   5.682576  283.60077
# 18      2       22   ...            0         0  11.365152  216.60484
#
#     vsa_other    vsa_pol     Weight  weinerPath  weinerPol  zagreb
# 0   12.949531  19.249496  310.84900        1050         30     102
# 2   36.550735  61.022110  362.47400        1295         41     126
# 3   42.243458  59.150364  355.41501         983         35     120
# 4   22.381124  24.524654  255.70799         624         25      94
# 5   11.190562  43.926376  423.56500        2659         49     164
# 6   25.239683  59.437412  324.34399        1583         32     120
# 8   24.140093  59.997055  497.64398        4018         54     190
# 9   24.140093  33.813168  434.34698        2338         47     154
# 12  43.111317  48.887096  362.42599        1631         44     136
# 18  21.408051  41.002750  314.36499        1107         34     114
#
# [10 rows x 188 columns]

# %%
# Demonstrate the dataset is balanced
n_pos = (balanced.ActivityScore >= 40).sum()
n_neg = (balanced.ActivityScore < 40).sum()
n_neg, n_pos
# Out:
# (4121, 4121)

# %%
# Repeat code with different seed number to demonstrate shuffling

indices2 = np.where(isozyme2c9.ActivityScore < 40)[0]
rng2 = np.random.RandomState(3489453655)  # sets seed for random number generator
rng2.shuffle(indices2)             # different seed numbers result in different shuffle
n_pos2 = (isozyme2c9.ActivityScore >= 40).sum()
balanced2 = isozyme2c9.drop(isozyme2c9.index[indices2[n_pos2:]])

balanced2.head(10)
# Out:
#        SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 2   842319             87  52.328274      4       0      6       0       42
# 3   842408             20  42.691135      4       0     11       0       31
# 4   842584             40  36.787930      3       0     17       0       28
# 5   842618             88  70.986168      5       0     17       2       64
# 6   842697             42  47.032688      6       0     17       0       40
# 7   842789             20  59.769032      3       0     12       0       52
# 8   842891              0  81.870926      6       0     11       2       75
# 9   842953             42  62.660240      3       0     12       1       52
# 10  842968              0  61.196651      3       4     12       0       52
# 12  843170             40  56.986618      4       0      6       0       52
#
#     a_don  a_heavy   ...      vsa_acid  vsa_base    vsa_don    vsa_hyd  \
# 2       0       24   ...      0.000000         0   0.000000  241.82869
# 3       0       22   ...      0.000000         0   0.000000  191.26006
# 4       2       18   ...      0.000000         0   0.000000  180.79523
# 5       0       31   ...      0.000000         0   0.000000  380.40643
# 6       1       24   ...      0.000000         0   5.682576  224.58302
# 7       3       28   ...      0.000000         0  17.047728  266.20810
# 8       1       36   ...      0.000000         0   5.682576  385.93207
# 9       1       29   ...      0.000000         0   0.000000  340.08496
# 10      0       31   ...     54.267685         0   0.000000  279.94351
# 12      1       26   ...      0.000000         0   5.682576  283.60077
#
#     vsa_other    vsa_pol     Weight  weinerPath  weinerPol  zagreb
# 2   36.550735  61.022110  362.47400        1295         41     126
# 3   42.243458  59.150364  355.41501         983         35     120
# 4   22.381124  24.524654  255.70799         624         25      94
# 5   11.190562  43.926376  423.56500        2659         49     164
# 6   25.239683  59.437412  324.34399        1583         32     120
# 7   43.339603  57.748489  380.44800        2253         40     142
# 8   24.140093  59.997055  497.64398        4018         54     190
# 9   24.140093  33.813168  434.34698        2338         47     154
# 10  44.575069  72.842117  423.42099        2656         51     158
# 12  43.111317  48.887096  362.42599        1631         44     136
#
# [10 rows x 188 columns]

# %% [markdown]
# ## Write files for analysis

# %%
balanced.to_csv("data/balanced2c9.csv", index=False)

# %% [markdown]
# ## Generate Training and Test Set

# %%
twoC9 = pd.read_csv("data/balanced2c9.csv")

# %%
twoC9.head()
# Out:
#       SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  a_count  \
# 0  842238             20  51.111824      1       0      6       1       46
# 1  842319             87  52.328274      4       0      6       0       42
# 2  842408             20  42.691135      4       0     11       0       31
# 3  842584             40  36.787930      3       0     17       0       28
# 4  842618             88  70.986168      5       0     17       2       64
#
#    a_don  a_heavy   ...     vsa_acid  vsa_base   vsa_don    vsa_hyd  \
# 0      1       21   ...            0         0  5.682576  286.85770
# 1      0       24   ...            0         0  0.000000  241.82869
# 2      0       22   ...            0         0  0.000000  191.26006
# 3      2       18   ...            0         0  0.000000  180.79523
# 4      0       31   ...            0         0  0.000000  380.40643
#
#    vsa_other    vsa_pol     Weight  weinerPath  weinerPol  zagreb
# 0  12.949531  19.249496  310.84900        1050         30     102
# 1  36.550735  61.022110  362.47400        1295         41     126
# 2  42.243458  59.150364  355.41501         983         35     120
# 3  22.381124  24.524654  255.70799         624         25      94
# 4  11.190562  43.926376  423.56500        2659         49     164
#
# [5 rows x 188 columns]

# %% [markdown]
# ### Shuffle and split dataset while preserving pandas index and metadata.

# %%
# Method adapted to Python3 from function by boates at https://gist.github.com/boates/5127281
N = len(twoC9)

# %%
l = list(range(N))

# %%
random.seed(76)
random.shuffle(l)

# %%
# get splitting indicies
# Here they are set to 80% training, 0% cross-validation and 20% test sets
trainLen = int(N*.8)
cvLen    = int(N*0.0)
testLen  = int(N*.2)

# %%
# get training, cv, and test sets
training = twoC9.ix[l[:trainLen]]
cv       = twoC9.ix[l[trainLen:trainLen+cvLen]]
test     = twoC9.ix[l[trainLen+cvLen:]]

# %%
# Examine training set
training.head()
# Out:
#            SID  ActivityScore       apol  a_acc  a_acid  a_aro  a_base  \
# 1850   4247169             42  61.799446      6       0     12       0
# 5193  14744505             23  50.819481      3       0     15       0
# 6950  17409970             44  48.782272      1       0     17       0
# 2595   4253667             20  37.195171      4       4     16       0
# 2956  11110647              0  50.529068      0       0     12       1
#
#       a_count  a_don  a_heavy   ...      vsa_acid  vsa_base    vsa_don  \
# 1850       53      2       31   ...      0.000000         0  11.365152
# 5193       41      1       24   ...      0.000000         0   0.000000
# 6950       39      0       21   ...      0.000000         0   0.000000
# 2595       26      0       22   ...     54.267685         0   0.000000
# 2956       40      0       21   ...      0.000000         0   0.000000
#
#          vsa_hyd  vsa_other    vsa_pol     Weight  weinerPath  weinerPol  \
# 1850  259.517090  63.639111  62.756004  422.44098        3436         47
# 5193  262.144440  12.949531  32.816418  339.41901        1482         37
# 6950  276.754210  13.166624   5.682576  294.42200        1043         28
# 2595   89.419365  76.123856  96.737106  332.32001        1103         33
# 2956  299.232030   0.000000   0.000000  316.87601         896         33
#
#       zagreb
# 1850     160
# 5193     130
# 6950     106
# 2595     116
# 2956     110
#
# [5 rows x 188 columns]

# %%
test.shape
# Out:
# (1649, 188)

# %%
# Check number of actives an inactives in test set
n_pos1 = (test.ActivityScore >= 40).sum()
n_neg1 = (test.ActivityScore < 40).sum()
n_neg1, n_pos1
# Out:
# (794, 855)

# %%
# Check number of actives and inactives in training set
n_pos2 = (training.ActivityScore >= 40).sum()
n_neg2 = (training.ActivityScore < 40).sum()
n_neg2, n_pos2
# Out:
# (3327, 3266)

# %% [markdown]
# ## Write resulting training and test set to files for use in all further analyses.

# %%
training.to_csv("data/training2c9.csv", index=False)
test.to_csv("data/test2c9.csv", index=False)
